# %%
import numpy as np 
import pandas as pd 
import json 
import csv 
import random 

from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences 
from tensorflow.keras.utils import to_categorical 
from tensorflow.keras import regularizers 

import pprint 
import tensorflow.compat.v1 as tf 
from tensorflow.python.framework import ops 
from sklearn.model_selection import train_test_split 
from sklearn import preprocessing 
tf.disable_eager_execution() 

# Reading the data 
data = pd.read_csv("news.csv") 
data.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
data = data.drop(["Unnamed: 0"], axis=1) 
data.head(5)
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
# encoding the labels 
le = preprocessing.LabelEncoder() 
le.fit(data['label']) 
data['label'] = le.transform(data['label'])

# %%
embedding_dim = 50
max_length = 54
trunc_type = 'post'
padding_type = 'post'
oov_tok = "<OOV>"
training_size = 3000
test_portion = .1

# %%
title = [] 
text = [] 
labels = [] 
for x in range(training_size): 
	title.append(data['title'][x]) 
	text.append(data['text'][x]) 
	labels.append(data['label'][x])

# %%
tokenizer1 = Tokenizer() 
tokenizer1.fit_on_texts(title) 
word_index1 = tokenizer1.word_index 
vocab_size1 = len(word_index1) 
sequences1 = tokenizer1.texts_to_sequences(title) 
padded1 = pad_sequences( 
	sequences1, padding=padding_type, truncating=trunc_type) 
split = int(test_portion * training_size) 
training_sequences1 = padded1[split:training_size] 
test_sequences1 = padded1[0:split] 
test_labels = labels[0:split] 
training_labels = labels[split:training_size]

# %%
print(padded1)
# Out:
# [[  48   58 1930 ...    0    0    0]
#  [ 183    1 3170 ...    0    0    0]
#  [ 446    2  243 ...    0    0    0]
#  ...
#  [   1 7547  455 ...    0    0    0]
#  [1115  321  614 ...    0    0    0]
#  [   5 2516   42 ...    0    0    0]]

# %%
embeddings_index = {} 
with open('glove.6B.50d.txt', encoding='utf-8', errors='replace') as f: 
	for line in f: 
		values = line.split() 
		word = values[0] 
		coefs = np.asarray(values[1:], dtype='float32') 
		embeddings_index[word] = coefs 

# Generating embeddings 
embeddings_matrix = np.zeros((vocab_size1+1, embedding_dim)) 
for word, i in word_index1.items(): 
	embedding_vector = embeddings_index.get(word) 
	if embedding_vector is not None: 
		embeddings_matrix[i] = embedding_vector

# %%
model = tf.keras.Sequential([ 
	tf.keras.layers.Embedding(vocab_size1+1, embedding_dim, 
							input_length=max_length, weights=[ 
								embeddings_matrix], 
							trainable=False), 
	tf.keras.layers.Dropout(0.2), 
	tf.keras.layers.Conv1D(64, 5, activation='relu'), 
	tf.keras.layers.MaxPooling1D(pool_size=4), 
	tf.keras.layers.LSTM(64), 
	tf.keras.layers.Dense(1, activation='sigmoid') 
]) 
model.compile(loss='binary_crossentropy', 
			optimizer='adam', metrics=['accuracy']) 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 54, 50)            377600
#
#  dropout (Dropout)           (None, 54, 50)            0
#
#  conv1d (Conv1D)             (None, 50, 64)            16064
#
#  max_pooling1d (MaxPooling1D  (None, 12, 64)           0
#  )
#
#  lstm (LSTM)                 (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 426,753
# Trainable params: 49,153
# Non-trainable params: 377,600
# _________________________________________________________________

# %%
num_epochs = 50

training_padded = np.array(training_sequences1) 
training_labels = np.array(training_labels) 
testing_padded = np.array(test_sequences1) 
testing_labels = np.array(test_labels) 

history = model.fit(training_padded, training_labels, 
					epochs=num_epochs, 
					validation_data=(testing_padded, 
									testing_labels), 
					verbose=2)
# Out:
# Train on 2700 samples, validate on 300 samples
# Epoch 1/50
# 2700/2700 - 2s - loss: 0.6471 - accuracy: 0.6170 - val_loss: 0.5706 - val_accuracy: 0.7000 - 2s/epoch - 671us/sample
# c:\Users\mahes\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\engine\training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# Epoch 2/50
# 2700/2700 - 1s - loss: 0.5833 - accuracy: 0.6896 - val_loss: 0.5117 - val_accuracy: 0.7233 - 1s/epoch - 375us/sample
# Epoch 3/50
# 2700/2700 - 1s - loss: 0.5376 - accuracy: 0.7300 - val_loss: 0.5479 - val_accuracy: 0.7200 - 969ms/epoch - 359us/sample
# Epoch 4/50
# 2700/2700 - 1s - loss: 0.5031 - accuracy: 0.7493 - val_loss: 0.4914 - val_accuracy: 0.7400 - 984ms/epoch - 364us/sample
# Epoch 5/50
# 2700/2700 - 1s - loss: 0.4473 - accuracy: 0.7893 - val_loss: 0.4977 - val_accuracy: 0.7700 - 979ms/epoch - 363us/sample
# Epoch 6/50
# 2700/2700 - 1s - loss: 0.4451 - accuracy: 0.7874 - val_loss: 0.4885 - val_accuracy: 0.7733 - 972ms/epoch - 360us/sample
# Epoch 7/50
# 2700/2700 - 1s - loss: 0.3610 - accuracy: 0.8433 - val_loss: 0.4804 - val_accuracy: 0.7667 - 987ms/epoch - 366us/sample
# Epoch 8/50
# 2700/2700 - 1s - loss: 0.3178 - accuracy: 0.8626 - val_loss: 0.4677 - val_accuracy: 0.7867 - 1s/epoch - 374us/sample
# Epoch 9/50
# 2700/2700 - 1s - loss: 0.2810 - accuracy: 0.8796 - val_loss: 0.4946 - val_accuracy: 0.7967 - 1s/epoch - 391us/sample
# Epoch 10/50
# 2700/2700 - 1s - loss: 0.2719 - accuracy: 0.8837 - val_loss: 0.5542 - val_accuracy: 0.7900 - 1s/epoch - 476us/sample
# Epoch 11/50
# 2700/2700 - 1s - loss: 0.2328 - accuracy: 0.9022 - val_loss: 0.6020 - val_accuracy: 0.7667 - 1s/epoch - 401us/sample
# Epoch 12/50
# 2700/2700 - 1s - loss: 0.2175 - accuracy: 0.9104 - val_loss: 0.5815 - val_accuracy: 0.7800 - 1s/epoch - 389us/sample
# Epoch 13/50
# 2700/2700 - 1s - loss: 0.1854 - accuracy: 0.9274 - val_loss: 0.5551 - val_accuracy: 0.7967 - 1s/epoch - 372us/sample
# Epoch 14/50
# 2700/2700 - 2s - loss: 0.1811 - accuracy: 0.9296 - val_loss: 0.6032 - val_accuracy: 0.7733 - 2s/epoch - 683us/sample
# Epoch 15/50
# 2700/2700 - 2s - loss: 0.1681 - accuracy: 0.9389 - val_loss: 0.6385 - val_accuracy: 0.7767 - 2s/epoch - 778us/sample
# Epoch 16/50
# 2700/2700 - 2s - loss: 0.1511 - accuracy: 0.9396 - val_loss: 0.6275 - val_accuracy: 0.7800 - 2s/epoch - 783us/sample
# Epoch 17/50
# 2700/2700 - 2s - loss: 0.1533 - accuracy: 0.9474 - val_loss: 0.6781 - val_accuracy: 0.7467 - 2s/epoch - 788us/sample
# Epoch 18/50
# 2700/2700 - 2s - loss: 0.1468 - accuracy: 0.9474 - val_loss: 0.6513 - val_accuracy: 0.7533 - 2s/epoch - 791us/sample
# Epoch 19/50
# 2700/2700 - 2s - loss: 0.1301 - accuracy: 0.9511 - val_loss: 0.6536 - val_accuracy: 0.7700 - 2s/epoch - 770us/sample
# Epoch 20/50
# 2700/2700 - 3s - loss: 0.1176 - accuracy: 0.9548 - val_loss: 0.6871 - val_accuracy: 0.8033 - 3s/epoch - 1ms/sample
# Epoch 21/50
# 2700/2700 - 3s - loss: 0.1189 - accuracy: 0.9522 - val_loss: 0.6226 - val_accuracy: 0.7967 - 3s/epoch - 976us/sample
# Epoch 22/50
# 2700/2700 - 2s - loss: 0.1240 - accuracy: 0.9474 - val_loss: 0.6817 - val_accuracy: 0.7833 - 2s/epoch - 788us/sample
# Epoch 23/50
# 2700/2700 - 2s - loss: 0.1262 - accuracy: 0.9478 - val_loss: 0.6645 - val_accuracy: 0.7867 - 2s/epoch - 793us/sample
# Epoch 24/50
# 2700/2700 - 2s - loss: 0.1166 - accuracy: 0.9530 - val_loss: 0.6914 - val_accuracy: 0.7733 - 2s/epoch - 790us/sample
# Epoch 25/50
# 2700/2700 - 2s - loss: 0.1047 - accuracy: 0.9589 - val_loss: 0.7100 - val_accuracy: 0.7633 - 2s/epoch - 706us/sample
# Epoch 26/50
# 2700/2700 - 2s - loss: 0.1030 - accuracy: 0.9656 - val_loss: 0.6983 - val_accuracy: 0.7800 - 2s/epoch - 756us/sample
# Epoch 27/50
# 2700/2700 - 2s - loss: 0.0946 - accuracy: 0.9685 - val_loss: 0.6914 - val_accuracy: 0.7700 - 2s/epoch - 789us/sample
# Epoch 28/50
# 2700/2700 - 2s - loss: 0.0952 - accuracy: 0.9630 - val_loss: 0.6851 - val_accuracy: 0.7933 - 2s/epoch - 650us/sample
# Epoch 29/50
# 2700/2700 - 2s - loss: 0.0911 - accuracy: 0.9678 - val_loss: 0.6359 - val_accuracy: 0.7700 - 2s/epoch - 717us/sample
# Epoch 30/50
# 2700/2700 - 2s - loss: 0.0936 - accuracy: 0.9659 - val_loss: 0.7289 - val_accuracy: 0.7567 - 2s/epoch - 745us/sample
# Epoch 31/50
# 2700/2700 - 2s - loss: 0.0866 - accuracy: 0.9700 - val_loss: 0.6469 - val_accuracy: 0.7667 - 2s/epoch - 794us/sample
# Epoch 32/50
# 2700/2700 - 2s - loss: 0.0787 - accuracy: 0.9696 - val_loss: 0.7401 - val_accuracy: 0.7833 - 2s/epoch - 758us/sample
# Epoch 33/50
# 2700/2700 - 2s - loss: 0.0837 - accuracy: 0.9719 - val_loss: 0.7288 - val_accuracy: 0.7867 - 2s/epoch - 751us/sample
# Epoch 34/50
# 2700/2700 - 2s - loss: 0.0901 - accuracy: 0.9681 - val_loss: 0.6989 - val_accuracy: 0.7733 - 2s/epoch - 773us/sample
# Epoch 35/50
# 2700/2700 - 2s - loss: 0.0875 - accuracy: 0.9663 - val_loss: 0.6725 - val_accuracy: 0.8000 - 2s/epoch - 798us/sample
# Epoch 36/50
# 2700/2700 - 2s - loss: 0.0791 - accuracy: 0.9715 - val_loss: 0.7027 - val_accuracy: 0.7700 - 2s/epoch - 773us/sample
# Epoch 37/50
# 2700/2700 - 2s - loss: 0.0835 - accuracy: 0.9707 - val_loss: 0.9723 - val_accuracy: 0.7467 - 2s/epoch - 773us/sample
# Epoch 38/50
# 2700/2700 - 2s - loss: 0.0799 - accuracy: 0.9730 - val_loss: 0.7674 - val_accuracy: 0.7933 - 2s/epoch - 761us/sample
# Epoch 39/50
# 2700/2700 - 2s - loss: 0.0751 - accuracy: 0.9748 - val_loss: 0.9384 - val_accuracy: 0.7367 - 2s/epoch - 754us/sample
# Epoch 40/50
# 2700/2700 - 2s - loss: 0.0852 - accuracy: 0.9737 - val_loss: 0.7841 - val_accuracy: 0.7700 - 2s/epoch - 758us/sample
# Epoch 41/50
# 2700/2700 - 2s - loss: 0.0662 - accuracy: 0.9800 - val_loss: 0.7043 - val_accuracy: 0.7833 - 2s/epoch - 823us/sample
# Epoch 42/50
# 2700/2700 - 2s - loss: 0.0724 - accuracy: 0.9730 - val_loss: 0.7638 - val_accuracy: 0.7633 - 2s/epoch - 804us/sample
# Epoch 43/50
# 2700/2700 - 1s - loss: 0.0620 - accuracy: 0.9767 - val_loss: 0.8020 - val_accuracy: 0.7733 - 1s/epoch - 405us/sample
# Epoch 44/50
# 2700/2700 - 1s - loss: 0.0843 - accuracy: 0.9715 - val_loss: 0.7348 - val_accuracy: 0.7567 - 1s/epoch - 421us/sample
# Epoch 45/50
# 2700/2700 - 1s - loss: 0.0648 - accuracy: 0.9778 - val_loss: 0.7788 - val_accuracy: 0.7900 - 1s/epoch - 437us/sample
# Epoch 46/50
# 2700/2700 - 1s - loss: 0.0668 - accuracy: 0.9800 - val_loss: 0.7536 - val_accuracy: 0.7700 - 1s/epoch - 406us/sample
# Epoch 47/50
# 2700/2700 - 1s - loss: 0.0669 - accuracy: 0.9774 - val_loss: 0.7144 - val_accuracy: 0.7533 - 1s/epoch - 452us/sample
# Epoch 48/50
# 2700/2700 - 1s - loss: 0.0615 - accuracy: 0.9763 - val_loss: 0.8720 - val_accuracy: 0.7633 - 1s/epoch - 427us/sample
# Epoch 49/50
# 2700/2700 - 1s - loss: 0.0715 - accuracy: 0.9752 - val_loss: 0.7658 - val_accuracy: 0.7633 - 1s/epoch - 393us/sample
# Epoch 50/50
# 2700/2700 - 1s - loss: 0.0549 - accuracy: 0.9826 - val_loss: 0.7971 - val_accuracy: 0.7533 - 1s/epoch - 437us/sample

# %%
# sample text to check if fake or not 
X = "The Battle of New York: Why This Primary Matters"

# detection 
sequences = tokenizer1.texts_to_sequences([X])[0] 
sequences = pad_sequences([sequences], maxlen=54, 
						padding=padding_type, 
						truncating=trunc_type) 
if(model.predict(sequences, verbose=0)[0][0] >= 0.5): 
	print("This news is True") 
else: 
	print("This news is false")
# Out:
# This news is True
