# %% [markdown]
# # Case Study 2
# ###                                                                                                                                  - 32566 Mahesh Shriram

# %% [markdown]
# ### ------------------------------------------------------------------------------------------------------------------------------------------------------
# ## For an employee dataset, create a measure of central tendency and its measure of dispersion for statistical analysis of given data.
# ### ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('employee_data.csv')
df.head()
# Out:
#    id groups  age  healthy_eating  active_lifestyle  salary
# 0   0      A   36               5                 5    2297
# 1   1      A   55               3                 5    1134
# 2   2      A   61               8                 1    4969
# 3   3      O   29               3                 6     902
# 4   4      O   34               6                 2    3574

# %%
df.shape
# Out:
# (1000, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1000 non-null   int64
#  1   groups            1000 non-null   object
#  2   age               1000 non-null   int64
#  3   healthy_eating    1000 non-null   int64
#  4   active_lifestyle  1000 non-null   int64
#  5   salary            1000 non-null   int64
# dtypes: int64(5), object(1)
# memory usage: 47.0+ KB

# %%
df.describe()
# Out:
#                 id          age  healthy_eating  active_lifestyle      salary
# count  1000.000000  1000.000000     1000.000000       1000.000000  1000.00000
# mean    499.500000    41.155000        4.944000          5.683000  2227.46100
# std     288.819436    13.462995        2.013186          2.048587  1080.20976
# min       0.000000    18.000000        0.000000          0.000000   553.00000
# 25%     249.750000    30.000000        4.000000          4.000000  1360.00000
# 50%     499.500000    41.000000        5.000000          6.000000  2174.00000
# 75%     749.250000    53.000000        6.000000          7.000000  2993.75000
# max     999.000000    64.000000       10.000000         10.000000  5550.00000

# %%
df.isnull().sum()
# Out:
# id                  0
# groups              0
# age                 0
# healthy_eating      0
# active_lifestyle    0
# salary              0
# dtype: int64

# %%
mean_age = df['age'].mean()
print("Mean Age is: ",mean_age)
# Out:
# Mean Age is:  41.155

# %%
mean_salary = df['salary'].mean()
print("Mean Salary is: ",mean_salary)
# Out:
# Mean Salary is:  2227.461

# %%
plt.boxplot(df['age'])
plt.show()

# %%
plt.boxplot(df['salary'])
plt.show()

# %%
plt.scatter(x=df['age'],y=df['salary'])
plt.show()

# %%
plt.hist(df['salary'])
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x=df['age'],y=df['healthy_eating'],hue=df['groups'])
plt.show()
